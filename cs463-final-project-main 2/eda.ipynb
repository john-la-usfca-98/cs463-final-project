# %%
import os, sys
import pandas as pd

dir = os.listdir("data/color")
array = []
df = pd.DataFrame()

photos = []
condition = []
disease = []
healthy = 0
diseased = ""

for file in dir:
    if file != ".DS_Store":
        dir_photos = os.listdir("data/color/" + file)
        if file.__contains__("healthy"):
            healthy = 1
        else:
            healthy = 0

        diseased = (file.split("___"))[1]
        
        for photo in dir_photos:
           condition.append(healthy)
           disease.append(diseased)
           photos.append(photo)

df['Photo'] = photos
df['Disease'] = disease
df['Condition'] = condition

df
# Out:
#                                                    Photo             Disease  \
# 0      c6fc37bf-8462-49c9-ac5c-a5f078e34ea4___Com.G_T...         Target_Spot
# 1      fb967f21-6c02-4bd3-9145-ee91db7eb2c8___Com.G_T...         Target_Spot
# 2      ac946977-3f2b-4500-8920-607173e37def___Com.G_T...         Target_Spot
# 3      d26e6749-f1ca-406c-b052-55ee39836f78___Com.G_T...         Target_Spot
# 4      bb162385-0a45-4051-b352-dcba2ff7d66c___Com.G_T...         Target_Spot
# ...                                                  ...                 ...
# 16030  85908ad9-57a4-402e-b9c3-3907b452d26b___JR_Sept...  Septoria_leaf_spot
# 16031  83e998a6-37f5-47f1-9da5-165c3a4c19fd___Matt.S_...  Septoria_leaf_spot
# 16032  89d94469-6bd0-4b98-8736-bf9a1247271f___Matt.S_...  Septoria_leaf_spot
# 16033  dbc37452-1ff6-4ea9-a6ff-3c2d1f621bde___Matt.S_...  Septoria_leaf_spot
# 16034  d16a363b-66e1-4206-89f8-31b2b4fadd5b___Matt.S_...  Septoria_leaf_spot
#
#        Condition
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 16030          0
# 16031          0
# 16032          0
# 16033          0
# 16034          0
#
# [16035 rows x 3 columns]
